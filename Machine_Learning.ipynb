# %%
# Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# Read in the data
data = pd.read_csv('used_cars_data.csv', index_col='vin')
# Out:
# F:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.count()
# Out:
# back_legroom            2840771
# bed                       19568
# bed_height               429098
# bed_length               429098
# body_type               2986497
#                          ...
# wheel_system            2853308
# wheel_system_display    2853308
# wheelbase               2840771
# width                   2840771
# year                    3000040
# Length: 65, dtype: int64

# %%
#Data cleanup
data = data.drop_duplicates().copy()

# %%
# Drop mostly null columns
percentage = 50
min_count =  int(((100-percentage)/100)*data.shape[0] + 1) 
dataDropped = data.dropna(axis=1, thresh=min_count)

# %%
# checking how many null values are in the dataframe that are over 0%
percentage = dataDropped.isna().sum()/dataDropped.shape[0]*100

pd.DataFrame(percentage[percentage > 0])
# Out:
#                               0
# back_legroom           5.308867
# body_type              0.451400
# city_fuel_economy     16.375933
# description            2.596667
# engine_cylinders       3.352667
# engine_displacement    5.746100
# engine_type            3.352667
# exterior_color         0.000867
# fleet                 47.552633
# frame_damaged         47.552633
# franchise_make        19.087233
# front_legroom          5.308867
# fuel_tank_volume       5.308867
# fuel_type              2.757467
# has_accidents         47.552633
# height                 5.308867
# highway_fuel_economy  16.375933
# horsepower             5.746100
# interior_color         0.005500
# isCab                 47.552633
# length                 5.308867
# main_picture_url      12.302867
# major_options          6.668200
# maximum_seating        5.308867
# mileage                4.812900
# power                 16.047400
# salvage               47.552633
# seller_rating          1.362400
# sp_id                  0.003200
# theft_title           47.552633
# torque                17.259600
# transmission           2.139467
# transmission_display   2.139467
# trimId                 3.860833
# trim_name              3.876400
# wheel_system           4.891000
# wheel_system_display   4.891000
# wheelbase              5.308867
# width                  5.308867

# %%
# Drop less useful rows
dataDropped.drop('description', axis=1, inplace=True)
dataDropped.drop('engine_cylinders', axis=1, inplace=True)
dataDropped.drop('engine_displacement', axis=1, inplace=True)
dataDropped.drop('engine_type', axis=1, inplace=True)
dataDropped.drop('exterior_color', axis=1, inplace=True)
dataDropped.drop('fleet', axis=1, inplace=True)
dataDropped.drop('frame_damaged', axis=1, inplace=True)
dataDropped.drop('has_accidents', axis=1, inplace=True)
dataDropped.drop('interior_color', axis=1, inplace=True)
dataDropped.drop('isCab', axis=1, inplace=True)
dataDropped.drop('franchise_make', axis=1, inplace=True)
dataDropped.drop('main_picture_url', axis=1, inplace=True)
dataDropped.drop('major_options', axis=1, inplace=True)
dataDropped.drop('salvage', axis=1, inplace=True)
dataDropped.drop('seller_rating', axis=1, inplace=True)
dataDropped.drop('sp_id', axis=1, inplace=True)
dataDropped.drop('theft_title', axis=1, inplace=True)
dataDropped.drop('transmission', axis=1, inplace=True)
dataDropped.drop('transmission_display', axis=1, inplace=True)
dataDropped.drop('trimId', axis=1, inplace=True)
dataDropped.drop('trim_name', axis=1, inplace=True)
dataDropped.drop('wheel_system_display', axis=1, inplace=True)
dataDropped.drop('power', axis=1, inplace=True)

# %%
dataDropped.drop('city', axis=1, inplace=True)
dataDropped.drop('dealer_zip', axis=1, inplace=True)
dataDropped.drop('franchise_dealer', axis=1, inplace=True)
dataDropped.drop('is_new', axis=1, inplace=True)
dataDropped.drop('listed_date', axis=1, inplace=True)
dataDropped.drop('listing_color', axis=1, inplace=True)
dataDropped.drop('sp_name', axis=1, inplace=True)
dataDropped.drop('longitude', axis=1, inplace=True)
dataDropped.drop('latitude', axis=1, inplace=True)
dataDropped.drop('listing_id', axis=1, inplace=True)

# %%
# checking how many null values are in the dataframe that are over 0%
percentage = dataDropped.isna().sum()/dataDropped.shape[0]*100

pd.DataFrame(percentage[percentage > 0])
# Out:
#                               0
# back_legroom           5.308867
# body_type              0.451400
# city_fuel_economy     16.375933
# front_legroom          5.308867
# fuel_tank_volume       5.308867
# fuel_type              2.757467
# height                 5.308867
# highway_fuel_economy  16.375933
# horsepower             5.746100
# length                 5.308867
# maximum_seating        5.308867
# mileage                4.812900
# torque                17.259600
# wheel_system           4.891000
# wheelbase              5.308867
# width                  5.308867

# %%
#Fill in the rest of the missing values with the mean/most common values

#back_legroom
dataDropped['back_legroom'] = dataDropped['back_legroom'].str.split(' ').str[0]
dataDropped['back_legroom'].replace('--', np.nan , inplace=True)
dataDropped['back_legroom'] = pd.to_numeric(dataDropped['back_legroom'], downcast='float')
dataDropped['back_legroom'].fillna(dataDropped['back_legroom'].mean(), inplace=True)

#body_type
dataDropped['body_type'].replace(np.nan, 'SUV / Crossover', inplace=True)

#fuel economy
dataDropped['city_fuel_economy'].replace(np.nan, dataDropped['city_fuel_economy'].mean(), inplace=True)
dataDropped['highway_fuel_economy'].fillna(dataDropped['highway_fuel_economy'].mean(), inplace=True)
dataDropped['combined_fuel_economy'] = (dataDropped['city_fuel_economy'] + dataDropped['highway_fuel_economy'])/2 
dataDropped.drop(['city_fuel_economy','highway_fuel_economy'], axis=1, inplace=True)

#front_legroom
dataDropped['front_legroom'] = dataDropped['front_legroom'].str.split(' ').str[0]
dataDropped['front_legroom'].replace("--", np.nan , inplace=True)
dataDropped['front_legroom'] = pd.to_numeric(dataDropped['front_legroom'], downcast='float')
dataDropped['front_legroom'].fillna(dataDropped['front_legroom'].mean(), inplace=True)

#fuel_tank type
dataDropped['fuel_type'].fillna("Gasoline", inplace=True)

#fuel_tank
dataDropped['fuel_tank_volume'] = dataDropped['fuel_tank_volume'].str.split(' ').str[0]
dataDropped['fuel_tank_volume'].replace("--", np.nan , inplace=True)
dataDropped['fuel_tank_volume'] = pd.to_numeric(dataDropped['fuel_tank_volume'], downcast='float')
dataDropped.loc[(dataDropped['fuel_type'] == "Electric"), 'fuel_tank_volume'] = 0
dataDropped['fuel_tank_volume'].fillna(dataDropped.groupby('fuel_type')['fuel_tank_volume'].transform('mean'), inplace=True)

#height
dataDropped['height'] = dataDropped['height'].str.split(' ').str[0]
dataDropped['height'].replace("--", np.nan , inplace=True)
dataDropped['height'] = pd.to_numeric(dataDropped['height'], downcast='float')
dataDropped['height'].fillna(dataDropped['height'].mean(), inplace=True)

#horsepower
dataDropped['horsepower'].fillna(dataDropped['horsepower'].mode()[0], inplace=True)

#length
dataDropped['length'] = dataDropped['length'].str.split(' ').str[0]
dataDropped['length'].replace("--", np.nan , inplace=True)
dataDropped['length'] = pd.to_numeric(dataDropped['length'], downcast='float')
dataDropped['length'].fillna(dataDropped['length'].median(), inplace=True)

#maximum_seating
dataDropped['maximum_seating'].replace("--", np.nan , inplace=True)
dataDropped['maximum_seating'].fillna("5 seats", inplace=True)
dataDropped['maximum_seating'] = dataDropped['maximum_seating'].str.replace(" seats", "")
dataDropped['maximum_seating'] = pd.to_numeric(dataDropped['maximum_seating'], downcast='integer')

#mileage
# using the interquartile range to remove outliers
q1 = dataDropped['mileage'].quantile(0.25)
q3 = dataDropped['mileage'].quantile(0.75)
# calculating the interquartile range
iqr = q3 - q1
# removing outliers
dataDropped = dataDropped[(dataDropped['mileage'] >= q1 - 1.5*iqr) & (dataDropped['mileage'] <= q3 + 1.5*iqr)]
dataDropped['mileage'].fillna(dataDropped['mileage'].mean(), inplace=True)

#torque
dataDropped['torque'] = dataDropped['torque'].str.split(" ").str[0]
dataDropped['torque'] = dataDropped['torque'].astype(float)
dataDropped['torque'].fillna(dataDropped['torque'].mean(), inplace=True)

#wheel_system
dataDropped['wheel_system'].fillna("FWD", inplace=True)

#wheel base
dataDropped['wheelbase'] = dataDropped['wheelbase'].str.split(" ").str[0]
dataDropped['wheelbase'].replace("--", np.nan, inplace=True)
dataDropped['wheelbase'] = dataDropped['wheelbase'].astype(float)
dataDropped['wheelbase'].fillna(dataDropped['wheelbase'].median(), inplace=True)

#width
dataDropped['width'] = dataDropped['width'].str.split(" ").str[0]
dataDropped['width'].replace("--", np.nan, inplace=True)
dataDropped['width'] = dataDropped['width'].astype(float)
dataDropped['width'].fillna(dataDropped['width'].mode()[0], inplace=True)

# %%
# instantiating the value counts
top_20 = dataDropped['model_name'].value_counts()

# creating a list of the top 20 models
top_20 = top_20[:20].index
 
# creating a function to return the top 20 models
def top_20_model(model):
    if model in top_20:
        return model
    else:
        return 'Other'
     
# applying the function to the column
dataDropped['model_name'] = dataDropped['model_name'].apply(top_20_model)

# %%
dataDropped.to_csv('cleaned_dataset.csv', index=True)

# %%
cat_col = dataDropped.select_dtypes(include='object').columns

for col in cat_col:
    print(col)
    dummies = pd.get_dummies(dataDropped[col], prefix=col, drop_first=True)
    dataDropped = pd.concat([dataDropped, dummies], axis=1)
    dataDropped.drop(col, axis=1, inplace=True)
# Out:
# Index([], dtype='object')

# %%
matrix = pd.DataFrame(dataDropped.corr()['price'].sort_values(ascending=False)).style.background_gradient(cmap='coolwarm')
matrix
# Out:
# <style type="text/css">
# #T_401eb_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_401eb_row1_col0 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_401eb_row2_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_401eb_row3_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_401eb_row4_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_401eb_row5_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_401eb_row6_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_401eb_row7_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_401eb_row8_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_401eb_row9_col0, #T_401eb_row10_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_401eb_row11_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_401eb_row12_col0 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_401eb_row13_col0, #T_401eb_row14_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_401eb_row15_col0, #T_401eb_row16_col0, #T_401eb_row17_col0, #T_401eb_row18_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_401eb_row19_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_401eb_row20_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_401eb_row21_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_401eb_row22_col0, #T_401eb_row23_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_401eb_row24_col0, #T_401eb_row25_col0, #T_401eb_row26_col0, #T_401eb_row27_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_401eb_row28_col0, #T_401eb_row29_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_401eb_row30_col0, #T_401eb_row31_col0, #T_401eb_row32_col0, #T_401eb_row33_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_401eb_row34_col0, #T_401eb_row35_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_401eb_row36_col0, #T_401eb_row37_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_401eb_row38_col0, #T_401eb_row39_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_401eb_row40_col0, #T_401eb_row41_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_401eb_row42_col0, #T_401eb_row43_col0, #T_401eb_row44_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_401eb_row45_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_401eb_row46_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_401eb_row47_col0, #T_401eb_row48_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_401eb_row49_col0, #T_401eb_row50_col0, #T_401eb_row51_col0, #T_401eb_row52_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_401eb_row53_col0, #T_401eb_row54_col0, #T_401eb_row55_col0, #T_401eb_row56_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_401eb_row57_col0, #T_401eb_row58_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_401eb_row59_col0, #T_401eb_row60_col0, #T_401eb_row61_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_401eb_row62_col0, #T_401eb_row63_col0, #T_401eb_row64_col0, #T_401eb_row65_col0, #T_401eb_row66_col0, #T_401eb_row67_col0, #T_401eb_row68_col0, #T_401eb_row69_col0, #T_401eb_row70_col0, #T_401eb_row71_col0, #T_401eb_row72_col0, #T_401eb_row73_col0, #T_401eb_row74_col0, #T_401eb_row75_col0, #T_401eb_row76_col0, #T_401eb_row77_col0, #T_401eb_row78_col0, #T_401eb_row79_col0, #T_401eb_row80_col0, #T_401eb_row81_col0, #T_401eb_row82_col0, #T_401eb_row83_col0, #T_401eb_row84_col0, #T_401eb_row85_col0, #T_401eb_row86_col0, #T_401eb_row87_col0, #T_401eb_row88_col0, #T_401eb_row89_col0, #T_401eb_row90_col0, #T_401eb_row91_col0, #T_401eb_row92_col0, #T_401eb_row93_col0, #T_401eb_row94_col0, #T_401eb_row95_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_401eb_row96_col0, #T_401eb_row97_col0, #T_401eb_row98_col0, #T_401eb_row99_col0, #T_401eb_row100_col0, #T_401eb_row101_col0, #T_401eb_row102_col0, #T_401eb_row103_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_401eb_row104_col0, #T_401eb_row105_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_401eb_row106_col0, #T_401eb_row107_col0, #T_401eb_row108_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_401eb_row109_col0, #T_401eb_row110_col0, #T_401eb_row111_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_401eb_row112_col0, #T_401eb_row113_col0, #T_401eb_row114_col0, #T_401eb_row115_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_401eb_row116_col0, #T_401eb_row117_col0, #T_401eb_row118_col0, #T_401eb_row119_col0, #T_401eb_row120_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_401eb_row121_col0, #T_401eb_row122_col0, #T_401eb_row123_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_401eb_row124_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_401eb_row125_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_401eb_row126_col0, #T_401eb_row127_col0, #T_401eb_row128_col0, #T_401eb_row129_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_401eb_row130_col0, #T_401eb_row131_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_401eb_row132_col0, #T_401eb_row133_col0, #T_401eb_row134_col0, #T_401eb_row135_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_401eb_row136_col0, #T_401eb_row137_col0, #T_401eb_row138_col0, #T_401eb_row139_col0, #T_401eb_row140_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_401eb_row141_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_401eb_row142_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_401eb_row143_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_401eb_row144_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_401eb_row145_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_401eb_row146_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_401eb_row147_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_401eb_row148_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_401eb_row149_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_401eb_row150_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_401eb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_401eb_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_401eb_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row1" class="row_heading level0 row1" >horsepower</th>
#       <td id="T_401eb_row1_col0" class="data row1 col0" >0.568886</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row2" class="row_heading level0 row2" >torque</th>
#       <td id="T_401eb_row2_col0" class="data row2 col0" >0.508020</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row3" class="row_heading level0 row3" >fuel_tank_volume</th>
#       <td id="T_401eb_row3_col0" class="data row3 col0" >0.409685</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row4" class="row_heading level0 row4" >length</th>
#       <td id="T_401eb_row4_col0" class="data row4 col0" >0.383464</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row5" class="row_heading level0 row5" >wheelbase</th>
#       <td id="T_401eb_row5_col0" class="data row5 col0" >0.376618</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row6" class="row_heading level0 row6" >width</th>
#       <td id="T_401eb_row6_col0" class="data row6 col0" >0.357801</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row7" class="row_heading level0 row7" >height</th>
#       <td id="T_401eb_row7_col0" class="data row7 col0" >0.316320</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row8" class="row_heading level0 row8" >year</th>
#       <td id="T_401eb_row8_col0" class="data row8 col0" >0.266295</td>
#     </tr>
#     <tr>
#       <th id="T_401eb_level0_row9" class="row_heading level0 row9" >back_legroom</th>
#       <td id="T_401eb_row9_col0" class="data row9 col0" >0.257349</td>
#     </tr>
#     <tr>
#       <

# %%
lessData = dataDropped.sample(n=50000, random_state=42)
lessData
# Out:
#                    back_legroom  daysonmarket  front_legroom  \
# vin
# WAUBFAFL8FN008628     35.200001            41      41.299999
# 1VWBS7A33EC119460     39.099998            25      42.400002
# 1C6RR7KG5HS507094     40.299999            40      41.000000
# 4T1C11AK0LU383298     38.000000            14      42.099998
# JTEBU5JR0L5836692     32.900002             7      41.700001
# ...                         ...           ...            ...
# 1HGCV1F55JA065771     40.400002            12      42.299999
# 1GKKNKLA4HZ238603     39.700001            45      41.000000
# KL79MPSL5MB003365     39.400002           146      40.900002
# 1GCGTCEN0K1129638     35.799999            21      45.000000
# 1C4RDJAG2LC155391     38.599998           126      40.299999
#
#                    fuel_tank_volume     height  horsepower      length  \
# vin
# WAUBFAFL8FN008628              16.1  56.200001       220.0  185.100006
# 1VWBS7A33EC119460              18.5  58.500000       170.0  191.600006
# 1C6RR7KG5HS507094              26.0  77.500000       305.0  229.000000
# 4T1C11AK0LU383298              16.0  56.900002       203.0  192.100006
# JTEBU5JR0L5836692              23.0  71.500000       270.0  191.300003
# ...                             ...        ...         ...         ...
# 1HGCV1F55JA065771              14.8  57.099998       192.0  192.199997
# 1GKKNKLA4HZ238603              19.0  66.000000       193.0  193.600006
# KL79MPSL5MB003365              13.2  65.199997       155.0  173.500000
# 1GCGTCEN0K1129638              21.0  70.599998       308.0  212.699997
# 1C4RDJAG2LC155391              24.6  72.699997       293.0  201.199997
#
#                    maximum_seating  mileage    price  ...  model_name_Other  \
# vin                                                   ...
# WAUBFAFL8FN008628                5  31374.0  18470.0  ...                 1
# 1VWBS7A33EC119460                5  80800.0  11500.0  ...                 1
# 1C6RR7KG5HS507094                6  57943.0  24995.0  ...                 0
# 4T1C11AK0LU383298                5     10.0  22715.0  ...                 0
# JTEBU5JR0L5836692                5      0.0  43339.0  ...                 1
# ...                            ...      ...      ...  ...               ...
# 1HGCV1F55JA065771                5  29155.0  23990.0  ...                 0
# 1GKKNKLA4HZ238603                7  32987.0  21800.0  ...                 1
# KL79MPSL5MB003365                5    129.0  24758.0  ...                 1
# 1GCGTCEN0K1129638                5  35158.0  31000.0  ...                 1
# 1C4RDJAG2LC155391                7  10948.0  32999.0  ...                 1
#
#                    model_name_RAV4  model_name_Rogue  \
# vin
# WAUBFAFL8FN008628                0                 0
# 1VWBS7A33EC119460                0                 0
# 1C6RR7KG5HS507094                0                 0
# 4T1C11AK0LU383298                0                 0
# JTEBU5JR0L5836692                0                 0
# ...                            ...               ...
# 1HGCV1F55JA065771                0                 0
# 1GKKNKLA4HZ238603                0                 0
# KL79MPSL5MB003365                0                 0
# 1GCGTCEN0K1129638                0                 0
# 1C4RDJAG2LC155391                0                 0
#
#                    model_name_Silverado 1500  model_name_Trax  \
# vin
# WAUBFAFL8FN008628                          0                0
# 1VWBS7A33EC119460                          0                0
# 1C6RR7KG5HS507094                          0                0
# 4T1C11AK0LU383298                          0                0
# JTEBU5JR0L5836692                          0                0
# ...                                      ...              ...
# 1HGCV1F55JA065771                          0                0
# 1GKKNKLA4HZ238603                          0                0
# KL79MPSL5MB003365                          0                0
# 1GCGTCEN0K1129638                          0                0
# 1C4RDJAG2LC155391                          0                0
#
#                    model_name_Tucson  wheel_system_4X2  wheel_system_AWD  \
# vin
# WAUBFAFL8FN008628                  0                 0                 1
# 1VWBS7A33EC119460                  0                 0                 0
# 1C6RR7KG5HS507094                  0                 0                 0
# 4T1C11AK0LU383298                  0                 0                 0
# JTEBU5JR0L5836692                  0                 0                 0
# ...                              ...               ...               ...
# 1HGCV1F55JA065771                  0                 0                 0
# 1GKKNKLA4HZ238603                  0                 0                 0
# KL79MPSL5MB003365                  0                 0                 0
# 1GCGTCEN0K1129638                  0                 0                 0
# 1C4RDJAG2LC155391                  0                 0                 1
#
#                    wheel_system_FWD  wheel_system_RWD
# vin
# WAUBFAFL8FN008628                 0                 0
# 1VWBS7A33EC119460                 1                 0
# 1C6RR7KG5HS507094                 0                 0
# 4T1C11AK0LU383298                 1                 0
# JTEBU5JR0L5836692                 0                 0
# ...                             ...               ...
# 1HGCV1F55JA065771                 1                 0
# 1GKKNKLA4HZ238603                 1                 0
# KL79MPSL5MB003365                 1                 0
# 1GCGTCEN0K1129638                 0                 0
# 1C4RDJAG2LC155391                 0                 0
#
# [50000 rows x 151 columns]

# %%
dataDropped.to_csv('cleaned_dataset_dummy.csv', index=True)

# %%
lessData.to_csv('cleaned_dataset_shorten.csv', index=True)

# %%
x = lessData.drop('price', axis = 1)
y = lessData['price']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

forestModel = RandomForestRegressor(n_estimators=100, random_state=42)
forestModel.fit(xtrain, ytrain)

linearModel = LinearRegression()
linearModel.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
forestPredictions = forestModel.predict(xtest)
forestMAE = mean_absolute_error(ytest, forestPredictions)
print('Mean Absolute Error for Random Forest:', forestMAE)

linearPredictions = linearModel.predict(xtest)
linearMAE = mean_absolute_error(ytest, linearPredictions)
print('Mean Absolute Error for Linear Regression:', linearMAE)
# Out:
# Mean Absolute Error for Random Forest: 2956.6777851278707
# Mean Absolute Error for Linear Regression: 5544.367054850979
